# %%
import os
from pathlib import Path
import laspy
import numpy as np
from sklearn.cluster import DBSCAN

# %%
def run_dbscan(pathin, pathout, minpoints, r):
    """
    Runs DBSCAN clustering on the input LAS file, but only for points where the "significant change" scalar field is 1, 
    and writes the results to a new LAS file.

    Parameters:
    pathin (str): Path to the input LAS file.
    pathout (str): Path to the output LAS file.
    minpoints (int): Minimum number of points to form a dense region (minPts for DBSCAN).
    r (float): The maximum distance between two samples for one to be considered in the neighborhood of the other (epsilon for DBSCAN).
    """
    
    # Read the input LAS file
    with laspy.open(pathin) as las_file:
        las = las_file.read()

    # Extract XYZ coordinates and the "significant change" field
    points = np.vstack((las.x, las.y, las.z)).T

    try:
        significant_change = las['significant change']  # Replace with the correct field name if different
            # Filter points where "significant change" is 1
        points_filtered = points[significant_change == 1]

        if points_filtered.size == 0:
            print(f"No points with significant change in {pathin}")
            return
        flag = 0
    except:
        print(f"Error: 'significant_change' field not found in {pathin}")
        points_filtered = points
        flag = 1



    # Run DBSCAN clustering on filtered points
    dbscan = DBSCAN(eps=r, min_samples=minpoints)
    labels = dbscan.fit_predict(points_filtered)

    # Create a new array to hold cluster IDs for all points, set to -1 by default (meaning no cluster)
    cluster_ids = np.full(len(points), -1, dtype=np.int32)
    
    # Assign cluster IDs only to points that passed the "significant change" filter
    if not flag:
        cluster_ids[significant_change == 1] = labels

    # Add cluster labels as a new dimension to the LAS file
    las.add_extra_dim(laspy.ExtraBytesParams(name="ClusterID", type=np.int32))
    las.ClusterID = cluster_ids

    # Write the results to the output LAS file
    with laspy.open(pathout, mode='w', header=las.header) as las_output:
        las_output.write_points(las.points)

    print(f"DBSCAN clustering complete for significant change points. Results saved to {pathout}")


def process_erosion_files(base_dir, output_dir, minpoints, r):
    """
    Loops through subfolders in base_dir, finds all erosion2.las files, and runs DBSCAN on each.
    
    Parameters:
    base_dir (str): The path to the base directory containing m3c2_results subfolders.
    output_dir (str): The base path to the output directory where results will be stored.
    minpoints (int): Minimum number of points for DBSCAN.
    r (float): The maximum distance for DBSCAN.
    """
    
    # Loop through each subfolder in the m3c2_results directory
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.startswith('erosion2') and file.endswith('.las'):
                # Full path of the erosion2.las file
                erosion_file_path = os.path.join(root, file)
                # display(erosion_file_path)
                
                # Extract the subfolder name from the root path
                subfolder_name = Path(root).name
                # display(subfolder_name)

                # Define the output directory for this subfolder
                output_subfolder = os.path.join(output_dir, subfolder_name)
                # display(output_subfolder)

                # Create the output directory if it doesn't exist
                os.makedirs(output_subfolder, exist_ok=True)

                # Define the output LAS file path
                output_las_path = os.path.join(output_subfolder, f"{file[:-4]}_dbscan.las")
                # display(output_las_path)

                # Run DBSCAN on the erosion2.las file
                run_dbscan(erosion_file_path, output_las_path, minpoints, r)


# Example usage
base_dir = '/Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/m3c2_results'
output_dir = '/Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output'
minpoints = 20  # Minimum points for DBSCAN
r = .4  # Epsilon (maximum distance for DBSCAN)

process_erosion_files(base_dir, output_dir, minpoints, r)
# Out:
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190916_568_636_to_20190924_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220701_567_770_to_20220706_567_770/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190513_568_636_to_20190522_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180115_590_622_to_20180116_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190123_590_636_to_20190130_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190215_568_622_to_20190219_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180419_590_636_to_20180426_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190409_568_636_to_20190415_567_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220120_518_638_to_20220701_567_770/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230306_567_637_to_20230317_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230606_519_684_to_20230612_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191105_568_636_to_20191112_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170411_588_621_to_20170420_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211206_567_638_to_20211213_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240221_590_680_to_20240226_590_679/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180926_590_622_to_20181005_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230522_567_684_to_20230602_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191207_568_636_to_20191207_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191215_568_636_to_20191216_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191208_568_636_to_20191209_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220802_567_769_to_20220810_518_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190522_568_636_to_20190529_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190702_568_636_to_20190708_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210309_590_637_to_20210421_580_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181022_590_622_to_20181030_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191029_568_636_to_20191105_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180511_590_622_to_20180515_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220810_518_636_to_20220817_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231026_567_731_to_20231101_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200723_518_638_to_20200731_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230417_494_637_to_20230425_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191213_568_636_to_20191214_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171004_590_708_to_20171016_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210421_519_636_to_20210504_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181226_568_622_to_20190102_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180119_590_622_to_20180120_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230109_567_732_to_20230117_575_731/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170713_589_622_to_20170728_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180125_590_622_to_20180201_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240321_589_684_to_20240325_567_666/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190911_519_636_to_20190916_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180731_590_622_to_20180808_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230602_567_684_to_20230606_519_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191216_568_636_to_20191222_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230905_567_763_to_20230914_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180201_567_636_to_20180209_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180824_590_622_to_20180828_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171201_590_622_to_20171205_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171106_590_622_to_20171201_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240226_590_679_to_20240314_589_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221114_567_769_to_20221121_518_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191017_519_636_to_20191024_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20201118_519_636_to_20201217_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230217_518_684_to_20230303_589_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180223_590_622_to_20180227_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230914_567_768_to_20230918_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210913_588_683_to_20211005_565_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170811_590_622_to_20170907_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191009_568_636_to_20191017_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221128_567_768_to_20221206_518_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180711_594_622_to_20180716_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230724_567_762_to_20230801_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211213_567_769_to_20211217_567_766/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181008_590_622_to_20181016_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211012_567_637_to_20211027_567_708/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180906_519_622_to_20180910_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180426_590_622_to_20180502_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221013_566_684_to_20221019_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200805_568_636_to_20200814_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190924_567_636_to_20190930_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231018_567_735_to_20231026_567_731/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200219_568_636_to_20200222_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200127_568_636_to_20200202_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191112_519_636_to_20191118_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191202_567_639_to_20191206_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190227_568_622_to_20190304_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191211_518_638_to_20191213_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180309_589_623_to_20180314_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190813_568_636_to_20190819_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230815_567_684_to_20230822_567_745/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181105_567_638_to_20181114_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180910_590_622_to_20180921_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231208_567_727_to_20231213_519_667/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181005_590_622_to_20181008_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170329_590_620_to_20170411_588_621/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190315_568_622_to_20190321_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190722_519_636_to_20190731_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190107_568_622_to_20190114_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180615_590_622_to_20180628_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220712_518_637_to_20220718_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180814_590_622_to_20180824_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221025_567_769_to_20221101_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211011_567_630_to_20211012_567_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230106_518_684_to_20230109_567_732/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180117_590_622_to_20180117_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190119_590_622_to_20190123_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220908_567_769_to_20220913_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191024_568_636_to_20191029_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170517_590_622_to_20170613_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221206_518_638_to_20221212_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181030_590_622_to_20181105_567_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191214_590_636_to_20191214_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190930_568_636_to_20191009_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190610_568_636_to_20190617_519_636/erosion2_dbscan.las
# Error: 'significant_change' field not found in /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/m3c2_results/yearly_comparison/20221128_567_768_to_20230918_567_768/erosion2.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221128_567_768_to_20230918_567_768/erosion2_dbscan.las
# Error: 'significant_change' field not found in /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/m3c2_results/yearly_comparison/Original_20210913_588_683_to_20221128_567_768/erosion2.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/Original_20210913_588_683_to_20221128_567_768/erosion2_dbscan.las
# Error: 'significant_change' field not found in /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/m3c2_results/yearly_comparison/20210913_588_683_to_20221128_567_768/erosion2.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210913_588_683_to_20221128_567_768/erosion2_dbscan.las
# Error: 'significant_change' field not found in /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/m3c2_results/yearly_comparison/Original_20221128_567_768_to_20230918_567_768/erosion2.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/Original_20221128_567_768_to_20230918_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190401_568_636_to_20190409_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230322_589_684_to_20230417_494_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180110_590_622_to_20180115_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190321_590_636_to_20190327_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230510_567_666_to_20230515_589_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231013_573_768_to_20231018_567_735/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240208_590_666_to_20240212_589_683/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190219_568_622_to_20190222_594_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180828_590_622_to_20180906_519_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200210_590_636_to_20200213_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180921_590_636_to_20180926_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221005_565_769_to_20221013_566_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190502_568_636_to_20190513_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171031_590_636_to_20171106_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231127_567_745_to_20231208_567_727/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221107_567_769_to_20221114_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191208_568_636_to_20191208_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190829_568_636_to_20190905_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190529_568_636_to_20190605_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220926_518_638_to_20220928_567_755/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191214_568_636_to_20191215_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171219_590_622_to_20171221_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200110_568_636_to_20200114_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191213_568_636_to_20191213_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190415_567_638_to_20190423_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190327_568_622_to_20190401_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191211_568_636_to_20191211_518_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191210_568_636_to_20191211_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180118_590_622_to_20180119_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230801_567_769_to_20230815_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200205_568_636_to_20200210_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180216_590_622_to_20180223_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180628_590_622_to_20180711_594_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200731_568_636_to_20200805_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231116_519_745_to_20231127_567_745/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190206_568_622_to_20190212_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231003_567_684_to_20231013_573_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221101_567_769_to_20221107_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180515_590_622_to_20180524_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181114_590_622_to_20181121_567_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171016_590_622_to_20171031_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230425_567_684_to_20230502_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170420_590_622_to_20170517_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200223_568_636_to_20200225_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200222_568_636_to_20200223_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190423_568_636_to_20190502_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210126_567_768_to_20210208_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190617_519_636_to_20190624_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210208_519_636_to_20210309_590_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220928_567_755_to_20221005_565_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211122_567_764_to_20211130_567_667/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190708_568_636_to_20190716_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230202_518_683_to_20230217_518_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171212_590_622_to_20171219_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221019_567_769_to_20221025_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180724_590_622_to_20180731_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230104_567_745_to_20230106_518_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180319_590_622_to_20180328_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190304_568_622_to_20190308_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200228_568_636_to_20200304_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191206_568_636_to_20191206_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20201020_519_636_to_20201118_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230621_567_684_to_20230626_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200213_568_636_to_20200216_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190130_568_622_to_20190206_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240119_494_684_to_20240123_590_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190805_568_636_to_20190813_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190114_590_622_to_20190119_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230918_567_768_to_20230929_494_666/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230117_575_731_to_20230120_518_732/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211217_567_766_to_20211221_567_766/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200702_567_636_to_20200723_518_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191126_568_636_to_20191202_567_639/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211221_567_766_to_20220104_565_766/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230626_567_684_to_20230712_567_760/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191207_568_636_to_20191208_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240123_590_637_to_20240129_589_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180116_590_622_to_20180117_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200304_568_636_to_20200319_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190819_568_636_to_20190829_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190102_568_622_to_20190107_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230123_567_683_to_20230202_518_683/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230303_589_684_to_20230306_567_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210809_518_638_to_20210913_588_683/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230515_589_684_to_20230522_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180808_567_636_to_20180814_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190731_568_636_to_20190805_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221121_518_637_to_20221128_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220706_567_770_to_20220712_518_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180524_590_622_to_20180615_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200114_568_636_to_20200121_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180412_590_622_to_20180419_590_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190308_568_622_to_20190315_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240212_589_683_to_20240221_590_680/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181121_567_622_to_20181127_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240129_589_637_to_20240208_590_666/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200918_519_636_to_20201020_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230502_567_636_to_20230510_567_666/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211005_565_638_to_20211011_567_630/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230612_567_684_to_20230621_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221212_567_768_to_20221220_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200202_568_636_to_20200205_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220729_565_769_to_20220802_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180301_567_636_to_20180309_589_623/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190716_568_636_to_20190722_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231109_567_736_to_20231116_519_745/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191118_568_636_to_20191122_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211103_567_638_to_20211122_567_764/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181008_590_636_to_20181008_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190212_590_622_to_20190215_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220718_567_768_to_20220729_565_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190624_568_636_to_20190702_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230831_589_768_to_20230905_567_763/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181218_568_622_to_20181226_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190605_568_636_to_20190610_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191206_568_636_to_20191207_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200814_568_636_to_20200820_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191122_567_636_to_20191126_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170907_590_622_to_20170919_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230120_518_732_to_20230123_567_683/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220817_567_636_to_20220830_567_770/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200216_568_636_to_20200219_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190905_568_636_to_20190911_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180117_590_622_to_20180118_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170613_590_622_to_20170713_589_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200820_519_636_to_20200918_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191222_568_636_to_20191230_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231213_519_667_to_20240119_494_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181204_568_636_to_20181210_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200121_567_636_to_20200127_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20221220_567_768_to_20230104_567_745/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220104_565_766_to_20220114_567_668/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210504_568_636_to_20210714_567_637/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230718_519_768_to_20230724_567_762/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20231101_567_769_to_20231109_567_736/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211130_567_667_to_20211206_567_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20211027_567_708_to_20211103_567_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191209_568_636_to_20191209_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191230_568_636_to_20200110_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171205_590_622_to_20171212_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230317_567_684_to_20230322_589_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200319_568_636_to_20200702_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180716_590_622_to_20180724_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180405_590_622_to_20180412_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20200225_568_636_to_20200228_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180502_590_636_to_20180511_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210714_567_637_to_20210809_518_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180105_590_622_to_20180110_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230822_567_745_to_20230831_589_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180328_590_636_to_20180405_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20191209_568_636_to_20191210_568_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20190222_594_622_to_20190227_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230712_567_760_to_20230718_519_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180227_590_622_to_20180301_567_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180120_590_622_to_20180125_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20240314_589_684_to_20240321_589_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220114_567_668_to_20220120_518_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220830_567_770_to_20220908_567_769/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181210_568_622_to_20181218_568_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180209_590_622_to_20180216_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20180314_590_622_to_20180319_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20201217_519_636_to_20210126_567_768/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170728_590_622_to_20170811_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20230929_494_666_to_20231003_567_684/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20171221_568_622_to_20180105_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20210421_580_636_to_20210421_519_636/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181016_590_622_to_20181022_590_622/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170323_590_636_to_20170329_590_620/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20170919_590_622_to_20171004_590_708/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20220913_567_769_to_20220926_518_638/erosion2_dbscan.las
# DBSCAN clustering complete for significant change points. Results saved to /Volumes/group/LiDAR/LidarProcessing/changedetection_m3c2/grid_output/20181127_568_636_to_20181204_568_636/erosion2_dbscan.las

# %%
def makeGrid(pathin, pathout, polys, res):
    """
    Reads in a LAS file and a shapefile of polygons, calculates the mean of M3C2 distance 
    (absolute value) of points within each polygon for 1-meter height bins, and writes the result to a CSV file.

    Also plots the grid with Polygon ID on the x-axis and Z value on the y-axis, even for bins with no points.

    Parameters:
    pathin (str): Path to the input LAS file.
    pathout (str): Path to the output CSV file.
    polys (str): Path to the shapefile of polygons.
    """
    
    # Read the input LAS file
    with laspy.open(pathin) as las_file:
        las = las_file.read()

    # Extract XYZ coordinates, M3C2 distances, and ClusterID (assumed stored as extra fields)
    points = np.vstack((las.x, las.y, las.z, las['M3C2 distance'], las['ClusterID'])).T

    # Filter points where ClusterID is NOT -1
    points = points[points[:, 4] != -1]

    # Take absolute value of M3C2 Distance
    points[:, 3] = np.abs(points[:, 3])

    # Read the shapefile containing the polygons
    polygons = gpd.read_file(polys)
    # display(polygons)

    # Create a GeoDataFrame from the LAS points
    gdf_points = gpd.GeoDataFrame(
        points, 
        columns=['X', 'Y', 'Z', 'M3C2 Distance', 'ClusterID'],
        geometry=[Point(x, y) for x, y in zip(points[:, 0], points[:, 1])]
    )

    # Initialize a list to hold results for each polygon
    results = []

    # vertical bins
    z_bins = np.arange(0, 30, res)

    # Loop through each polygon and calculate the mean M3C2 distance for 1-meter Z-bins
    for i, polygon in polygons.iterrows():
        points_in_polygon = gdf_points[gdf_points.within(polygon.geometry)]

        # Define bins for height (Z-axis) from 0 to max height (e.g., 35 meters)
        # z_bins = np.arange(0, 30, 1)  # Create bins from 0 to 35 meters in 1-meter increments

        # Initialize a dictionary to store results for each polygon and each Z-bin
        polygon_result = {'Polygon_ID': polygon.index}
        # clusterID

        # Loop through each Z-bin (1-meter horizontal slice)
        for z in range(len(z_bins) - 1):
            # Select points within this 1-meter horizontal bin (Z-axis)
            points_in_bin = points_in_polygon[
                (points_in_polygon['Z'] >= z_bins[z]) & (points_in_polygon['Z'] < z_bins[z+1])
            ]
            
            # clusterID = points_in_bin['ClusterID'].mode().values[0] 

            if len(points_in_bin) > 0:
                # Compute the mean absolute M3C2 distance for this Z-bin
                mean_m3c2_in_bin = points_in_bin['M3C2 Distance'].median()
                cluster_id = points_in_bin['ClusterID'].mode().values[0]
            else:
                # If no points in this bin, set the mean distance to NaN
                mean_m3c2_in_bin = np.nan
                cluster_id = np.nan

            # Add the mean distance for this bin to the results dictionary
            polygon_result[f'M3C2_{z}m'] = [mean_m3c2_in_bin, cluster_id]
            # polygon_result[f'ClusterID_{z}m'] = cluster_id

        # Append the results for this polygon to the main results list
        results.append(polygon_result)

    # Create a DataFrame to store the results
    df_results = pd.DataFrame(results)
    # display(df_results)

    # Write the results to a CSV file
    df_results.to_csv(pathout, index=False)
    print(f"Results written to {pathout}")

    return df_results

# %%
polys = '/Users/cjmack/Documents/Papers/Cliffs/Code/Polygones/PolygonesDelMar1m.shp'
pathin = '/Users/cjmack/Documents/Papers/Cliffs/Scratch/erosion2_dbscan.las'
pathout = '/Users/cjmack/Documents/Papers/Cliffs/Scratch/Test.csv'
resolution = .1

output = makeGrid(pathin, pathout, polys, resolution)
